# %%
import pandas as pd
import numpy as np
import os

from datetime import datetime
import dask.dataframe as dd

import yfinance as yf
import plotly.graph_objects as go


def parse_file(file):
    col_names = ["Date", "Time", "Open", "High", "Low", "Close", "Volume"]

    raw_path = os.path.join(os.getcwd(), "d2", f"{file}.csv")
    updated_file_path = os.path.join(os.getcwd(), "d2/converted", f"{file}-updated.csv")

    exists = os.path.isfile(updated_file_path)

    args = {}

    if exists:
        args["parse_dates"] = True
        args["index_col"] = "Datetime"

    else:
        args["sep"] = ";"
        args["names"] = col_names
        header = None

    # print(exists, raw_path, updated_file_path)

    ticker_data = pd.read_csv(updated_file_path if exists else raw_path, **args)

    def convert_date(row):
        # print(row['Date']+' '+row['Time'])

        row["Datetime"] = datetime.strptime(
            row["Date"] + " " + row["Time"], "%d/%m/%Y %H:%M:%S"
        )

        return row

    if not exists:
        ticker_data = ticker_data.apply(
            convert_date, axis=1
        )

        ticker_data.to_csv(updated_file_path)

    ticker_data

    # dd.read_csv('data.csv', blocksize=25e6).to_parquet('data.parquet', engine='fastparquet')
    # print(dd.read_csv(raw_path, blocksize=25e6,).head())


parse_file("eurusd-5m")

# %%
import os 

files = os.listdir(os.path.join(os.getcwd(), "d2"))


for file in files: 
    
    print(file)
    
    try: 
        parse_file(file.split(".")[0])
    
    except Exception as e: 
        print(f"Error: {e} for {file}")
        print("Moving to the next file ...")
# Out:
# usdchf-4h.csv
# hang-seng1d-1987.csv
# Error: time data '29/06/2015 00:00' does not match format '%d/%m/%Y %H:%M:%S' for hang-seng1d-1987.csv
# Moving to the next file ...
# gc-15m.csv
# hang-seng30m-2007.csv
# Error: time data '26/06/2015 15:30' does not match format '%d/%m/%Y %H:%M:%S' for hang-seng30m-2007.csv
# Moving to the next file ...
# zw-30m.csv
# zw-5m.csv
# eurcad-1w.csv
# dlarind-15m.csv
# ny-5m.csv
# usdcad-30m.csv
# chfjpy-30m.csv
# eurusd-1w.csv
# btcusd-1m.csv
# zb-30m.csv
# zc-4h.csv
# zc-5m.csv
# gbpcad-1h.csv
# audcad-30m.csv
# zn-1m.csv
# ny-4h.csv
# zb-1m.csv
# dlarind-1h.csv
# zw-4h.csv
# xauusd-1h.csv
# ethusd-1d.csv
# bund-1w.csv
# ng-1d.csv
# Error: time data '14/11/1995 00:00' does not match format '%d/%m/%Y %H:%M:%S' for ng-1d.csv
# Moving to the next file ...
# ym-30m.csv
# zs-1w.csv
# cb-1mo.csv
# hg-15m.csv
# gbpusd-1h.csv
# ym-1w.csv
# usdchf-5m.csv
# bund-15m.csv
# nq-1w.csv
# usdjpy-1h.csv
# audjpy-1h.csv
# cl-1d.csv
# Error: time data '20/04/1983 00:00' does not match format '%d/%m/%Y %H:%M:%S' for cl-1d.csv
# Moving to the next file ...
# chfjpy-5m.csv
# pa-1mo.csv
# nzdusd-1mo.csv
# ethusd-1mo.csv
# vix-5m.csv
# hang-seng1d-1987-1mo.csv
# vix-4h.csv
# ny-15m.csv
# rb-1h.csv
# gbpchf-1m.csv
# Error: time data '07/07/2017 15:58' does not match format '%d/%m/%Y %H:%M:%S' for gbpchf-1m.csv
# Moving to the next file ...
# ftse100-30m.csv
# chfjpy-4h.csv
# cb-1w.csv
# hang-seng1d-1987-1w.csv
# euraud-1mo.csv
# dax-1w.csv
# pa-1w.csv
# rb-15m.csv
# dax-1mo.csv
# si-1d.csv
# Error: time data '25/02/1970 00:00' does not match format '%d/%m/%Y %H:%M:%S' for si-1d.csv
# Moving to the next file ...
# eurchf-1d.csv
# Error: time data '14/01/1991 00:00' does not match format '%d/%m/%Y %H:%M:%S' for eurchf-1d.csv
# Moving to the next file ...
# ftsemib-1m-2007.csv
# Error: time data '13/03/2007 09:00' does not match format '%d/%m/%Y %H:%M:%S' for ftsemib-1m-2007.csv
# Moving to the next file ...
# eurchf-1w.csv
# audusd-4h.csv
# usdjpy-1m.csv
# Error: time data '04/10/2015 15:05' does not match format '%d/%m/%Y %H:%M:%S' for usdjpy-1m.csv
# Moving to the next file ...
# si-1w.csv
# hang-seng4h-2007.csv
# Error: time data '26/06/2015 12:00' does not match format '%d/%m/%Y %H:%M:%S' for hang-seng4h-2007.csv
# Moving to the next file ...
# pa-1d.csv
# Error: time data '11/12/1995 00:00' does not match format '%d/%m/%Y %H:%M:%S' for pa-1d.csv
# Moving to the next file ...
# usdcad-4h.csv
# dax-1d.csv
# Error: time data '23/11/1990 00:00' does not match format '%d/%m/%Y %H:%M:%S' for dax-1d.csv
# Moving to the next file ...
# spx-4h.csv
# gc-4h.csv
# cb-1d.csv
# audjpy-1m.csv
# Error: time data '07/07/2017 15:58' does not match format '%d/%m/%Y %H:%M:%S' for audjpy-1m.csv
# Moving to the next file ...
# gbpchf-30m.csv
# mx-30m.csv
# nzdusd-4h.csv
# audcad-4h.csv
# es-4h.csv
# es-5m.csv
# audcad-5m.csv
# nzdusd-5m.csv
# gbpchf-1h.csv
# rb-1m.csv
# eurchf-30m.csv
# cl-1w.csv
# gc-5m.csv
# spx-5m.csv
# usdcad-5m.csv
# audusd-5m.csv
# nq-1d.csv
# Error: time data '30/06/1999 00:00' does not match format '%d/%m/%Y %H:%M:%S' for nq-1d.csv
# Moving to the next file ...
# spx-30m.csv
# ym-1d.csv
# Error: time data '03/04/2002 00:00' does not match format '%d/%m/%Y %H:%M:%S' for ym-1d.csv
# Moving to the next file ...
# eurusd-1mo.csv
# vix-15m.csv
# zs-1d.csv
# Error: time data '23/07/1970 00:00' does not match format '%d/%m/%Y %H:%M:%S' for zs-1d.csv
# Moving to the next file ...
# ng-1w.csv
# bund-1d.csv
# Error: time data '23/11/1990 00:00' does not match format '%d/%m/%Y %H:%M:%S' for bund-1d.csv
# Moving to the next file ...
# xauusd-30m.csv
# ethusd-1w.csv
# zc-30m.csv
# gbpjpy-5m.csv
# btcusd-15m.csv
# ftse100-4h.csv
# btcusd-1h.csv
# audjpy-1mo.csv
# gbpjpy-15m.csv
# gbpcad-1m.csv
# eurjpy-15m.csv
# hs-15m.csv
# eurusd-1d.csv
# Error: time data '04/01/1971 00:00' does not match format '%d/%m/%Y %H:%M:%S' for eurusd-1d.csv
# Moving to the next file ...
# zn-1h.csv
# ftse100-5m.csv
# usdjpy-1mo.csv
# gbpjpy-4h.csv
# eurcad-1d.csv
# Error: time data '09/10/1991 00:00' does not match format '%d/%m/%Y %H:%M:%S' for eurcad-1d.csv
# Moving to the next file ...
# dlarind-1m.csv
# zb-1h.csv
# xauusd-1m.csv
# gbpusd-1mo.csv
# nq-15m.csv
# gbpusd-1m.csv
# Error: time data '04/10/2015 15:03' does not match format '%d/%m/%Y %H:%M:%S' for gbpusd-1m.csv
# Moving to the next file ...
# audusd-15m.csv
# eurchf-5m.csv
# si-5m.csv
# eurgbp-1h.csv
# cl-4h.csv
# nzdusd-30m.csv
# ethusd-30m.csv
# ftsemib1d-2004-1w.csv
# pa-30m.csv
# vix-1d.csv
# audcad-1w.csv
# es-1w.csv
# ftse100-1mo.csv
# hang-seng-1m-2007.csv
# Error: time data '13/03/2007 05:00' does not match format '%d/%m/%Y %H:%M:%S' for hang-seng-1m-2007.csv
# Moving to the next file ...
# nzdusd-1w.csv
# euraud-1h.csv
# cl-5m.csv
# gc-1w.csv
# chfjpy-1d.csv
# Error: time data '21/12/1993 00:00' does not match format '%d/%m/%Y %H:%M:%S' for chfjpy-1d.csv
# Moving to the next file ...
# spx-1w.csv
# es-15m.csv
# usdcad-1w.csv
# dax-30m.csv
# eurchf-4h.csv
# audusd-1w.csv
# si-4h.csv
# euraud-30m.csv
# zw-1mo.csv
# usdchf-1d.csv
# Error: time data '04/01/1971 00:00' does not match format '%d/%m/%Y %H:%M:%S' for usdchf-1d.csv
# Moving to the next file ...
# nifty50-4h-2007.csv
# Error: time data '26/10/2007 04:00' does not match format '%d/%m/%Y %H:%M:%S' for nifty50-4h-2007.csv
# Moving to the next file ...
# ng-5m.csv
# ethusd-5m.csv
# hg-1h.csv
# gbpjpy-1w.csv
# eurcad-15m.csv
# zb-1mo.csv
# usdcad-1mo.csv
# zn-15m.csv
# chfjpy-1mo.csv
# mx-1m.csv
# ftsemib30m-2007.csv
# Error: time data '26/06/2015 15:00' does not match format '%d/%m/%Y %H:%M:%S' for ftsemib30m-2007.csv
# Moving to the next file ...
# zc-1d.csv
# Error: time data '23/07/1970 00:00' does not match format '%d/%m/%Y %H:%M:%S' for zc-1d.csv
# Moving to the next file ...
# hs-1h.csv
# kc-1m.csv
# audcad-1mo.csv
# ftse100-1w.csv
# ny-1d.csv
# Error: time data '08/12/2006 00:00' does not match format '%d/%m/%Y %H:%M:%S' for ny-1d.csv
# Moving to the next file ...
# gbpcad-15m.csv
# ethusd-4h.csv
# zw-1d.csv
# Error: time data '23/07/1970 00:00' does not match format '%d/%m/%Y %H:%M:%S' for zw-1d.csv
# Moving to the next file ...
# ng-4h.csv
# cb-30m.csv
# ym-1mo.csv
# eurjpy-1h.csv
# ym-4h.csv
# nq-4h.csv
# xauusd-1mo.csv
# zs-4h.csv
# bund-4h.csv
# ftsemib4h-2007.csv
# Error: time data '25/06/2015 17:00' does not match format '%d/%m/%Y %H:%M:%S' for ftsemib4h-2007.csv
# Moving to the next file ...
# zw-1w.csv
# hg-1m.csv
# spx-1mo.csv
# eurcad-5m.csv
# eurusd-30m.csv
# ny-1w.csv
# ftse100-1d.csv
# Error: time data '03/05/1984 00:00' does not match format '%d/%m/%Y %H:%M:%S' for ftse100-1d.csv
# Moving to the next file ...
# nifty50-1m-2007.csv
# Error: time data '26/10/2007 06:29' does not match format '%d/%m/%Y %H:%M:%S' for nifty50-1m-2007.csv
# Moving to the next file ...
# eurusd-5m.csv
# audjpy-30m.csv
# zc-1mo.csv
# mx-1h.csv
# cl-15m.csv
# hs-1m.csv
# zc-1w.csv
# usdjpy-30m.csv
# kc-1h.csv
# eurusd-4h.csv
# gbpjpy-1d.csv
# Error: time data '02/01/1991 00:00' does not match format '%d/%m/%Y %H:%M:%S' for gbpjpy-1d.csv
# Moving to the next file ...
# si-15m.csv
# ng-15m.csv
# eurcad-4h.csv
# gbpusd-30m.csv
# bund-5m.csv
# zs-5m.csv
# usdchf-1w.csv
# nq-5m.csv
# eurjpy-1m.csv
# Error: time data '07/07/2017 15:58' does not match format '%d/%m/%Y %H:%M:%S' for eurjpy-1m.csv
# Moving to the next file ...
# ym-5m.csv
# eurgbp-15m.csv
# audusd-1d.csv
# Error: time data '04/01/1971 00:00' does not match format '%d/%m/%Y %H:%M:%S' for audusd-1d.csv
# Moving to the next file ...
# usdcad-1d.csv
# Error: time data '04/01/1971 00:00' does not match format '%d/%m/%Y %H:%M:%S' for usdcad-1d.csv
# Moving to the next file ...
# dax-4h.csv
# pa-4h.csv
# nifty50-30m-2007.csv
# Error: time data '26/10/2007 06:15' does not match format '%d/%m/%Y %H:%M:%S' for nifty50-30m-2007.csv
# Moving to the next file ...
# eurgbp-1m.csv
# Error: time data '07/07/2017 15:58' does not match format '%d/%m/%Y %H:%M:%S' for eurgbp-1m.csv
# Moving to the next file ...
# spx-1d.csv
# chfjpy-1w.csv
# kc-15m.csv
# gc-1d.csv
# Error: time data '02/01/1975 00:00' does not match format '%d/%m/%Y %H:%M:%S' for gc-1d.csv
# Moving to the next file ...
# cb-4h.csv
# zs-15m.csv
# mx-1mo.csv
# nzdusd-1d.csv
# Error: time data '08/07/1991 00:00' does not match format '%d/%m/%Y %H:%M:%S' for nzdusd-1d.csv
# Moving to the next file ...
# gbpchf-1mo.csv
# es-1d.csv
# Error: time data '01/02/1983 00:00' does not match format '%d/%m/%Y %H:%M:%S' for es-1d.csv
# Moving to the next file ...
# audcad-1d.csv
# vix-1w.csv
# eurchf-1mo.csv
# euraud-1m.csv
# Error: time data '07/07/2017 15:58' does not match format '%d/%m/%Y %H:%M:%S' for euraud-1m.csv
# Moving to the next file ...
# cb-5m.csv
# usdchf-15m.csv
# pa-5m.csv
# dax-5m.csv
# audusd-1h.csv
# ng-1mo.csv
# usdcad-1h.csv
# audusd-30m.csv
# si-1mo.csv
# nq-30m.csv
# spx-1h.csv
# eurjpy-30m.csv
# gc-1h.csv
# hs-30m.csv
# gbpchf-5m.csv
# ftsemib1h-2007.csv
# Error: time data '26/06/2015 15:00' does not match format '%d/%m/%Y %H:%M:%S' for ftsemib1h-2007.csv
# Moving to the next file ...
# euraud-1w.csv
# nzdusd-1h.csv
# cl-1mo.csv
# es-1h.csv
# audcad-1h.csv
# btcusd-30m.csv
# vix-1m.csv
# zc-15m.csv
# gbpchf-4h.csv
# gbpjpy-30m.csv
# chfjpy-1m.csv
# Error: time data '07/07/2017 15:58' does not match format '%d/%m/%Y %H:%M:%S' for chfjpy-1m.csv
# Moving to the next file ...
# eurgbp-1w.csv
# vix-30m.csv
# spx-15m.csv
# xauusd-15m.csv
# usdchf-1m.csv
# Error: time data '04/10/2015 15:01' does not match format '%d/%m/%Y %H:%M:%S' for usdchf-1m.csv
# Moving to the next file ...
# eurjpy-1w.csv
# zb-5m.csv
# ftse100-1h.csv
# zn-5m.csv
# usdchf-1mo.csv
# eurchf-15m.csv
# btcusd-4h.csv
# zc-1m.csv
# hs-1w.csv
# mx-1d.csv
# gbpchf-15m.csv
# btcusd-5m.csv
# kc-1d.csv
# zn-4h.csv
# mx-15m.csv
# zs-1mo.csv
# gbpjpy-1h.csv
# ny-1m.csv
# hg-1w.csv
# zw-1m.csv
# zb-4h.csv
# eurgbp-1mo.csv
# usdchf-1h.csv
# rb-30m.csv
# gbpusd-5m.csv
# es-1mo.csv
# dlarind-5m.csv
# xauusd-5m.csv
# hg-1d.csv
# Error: time data '29/07/1988 00:00' does not match format '%d/%m/%Y %H:%M:%S' for hg-1d.csv
# Moving to the next file ...
# nifty50-1d-2007-1mo.csv
# ny-30m.csv
# ftse100-1m.csv
# ftse100-15m.csv
# gbpcad-5m.csv
# zc-1h.csv
# mx-1w.csv
# gbpcad-4h.csv
# hs-1d.csv
# ny-1h.csv
# gbpjpy-1m.csv
# Error: time data '16/12/2009 00:00' does not match format '%d/%m/%Y %H:%M:%S' for gbpjpy-1m.csv
# Moving to the next file ...
# dlarind-4h.csv
# zw-1h.csv
# xauusd-4h.csv
# gbpusd-4h.csv
# hang-seng15m-2007.csv
# Error: time data '26/06/2015 15:30' does not match format '%d/%m/%Y %H:%M:%S' for hang-seng15m-2007.csv
# Moving to the next file ...
# eurjpy-1d.csv
# Error: time data '28/06/1989 00:00' does not match format '%d/%m/%Y %H:%M:%S' for eurjpy-1d.csv
# Moving to the next file ...
# ym-15m.csv
# usdjpy-4h.csv
# audusd-1m.csv
# Error: time data '04/10/2015 15:02' does not match format '%d/%m/%Y %H:%M:%S' for audusd-1m.csv
# Moving to the next file ...
# bund-30m.csv
# usdcad-1m.csv
# Error: time data '04/10/2015 15:01' does not match format '%d/%m/%Y %H:%M:%S' for usdcad-1m.csv
# Moving to the next file ...
# spx-1m.csv
# eurgbp-1d.csv
# Error: time data '14/04/1995 00:00' does not match format '%d/%m/%Y %H:%M:%S' for eurgbp-1d.csv
# Moving to the next file ...
# converted
# Error: [Errno 2] No such file or directory: '/Users/jarmanrandhawa/work/retracer/d2/converted.csv' for converted
# Moving to the next file ...
# hg-30m.csv
# gc-1m.csv
# audcad-15m.csv
# audjpy-4h.csv
# gbpcad-1mo.csv
# rb-5m.csv
# nifty50-1h-2007.csv
# Error: time data '26/10/2007 06:00' does not match format '%d/%m/%Y %H:%M:%S' for nifty50-1h-2007.csv
# Moving to the next file ...
# hang-seng5m-2007.csv
# Error: time data '26/06/2015 15:30' does not match format '%d/%m/%Y %H:%M:%S' for hang-seng5m-2007.csv
# Moving to the next file ...
# nzdusd-1m.csv
# Error: time data '07/07/2017 15:58' does not match format '%d/%m/%Y %H:%M:%S' for nzdusd-1m.csv
# Moving to the next file ...
# audcad-1m.csv
# es-1m.csv
# usdcad-15m.csv
# vix-1h.csv
# chfjpy-15m.csv
# zn-1mo.csv
# dlarind-30m.csv
# euraud-1d.csv
# Error: time data '09/10/1991 00:00' does not match format '%d/%m/%Y %H:%M:%S' for euraud-1d.csv
# Moving to the next file ...
# rb-4h.csv
# audjpy-5m.csv
# chfjpy-1h.csv
# eurcad-1mo.csv
# zb-15m.csv
# gc-30m.csv
# zw-15m.csv
# hang-seng1d-1987-1w 2.csv
# usdjpy-5m.csv
# nq-1h.csv
# ym-1h.csv
# gbpusd-1w.csv
# zs-1h.csv
# bund-1h.csv
# nifty50-1d-2007.csv
# Error: time data '26/10/2007 00:00' does not match format '%d/%m/%Y %H:%M:%S' for nifty50-1d-2007.csv
# Moving to the next file ...
# dlarind-1w.csv
# xauusd-1w.csv
# btcusd-1d.csv
# hang-seng1h-2007.csv
# Error: time data '26/06/2015 15:00' does not match format '%d/%m/%Y %H:%M:%S' for hang-seng1h-2007.csv
# Moving to the next file ...
# kc-5m.csv
# nifty50-5m-2007.csv
# Error: time data '26/10/2007 06:25' does not match format '%d/%m/%Y %H:%M:%S' for nifty50-5m-2007.csv
# Moving to the next file ...
# usdchf-30m.csv
# mx-4h.csv
# gbpcad-1w.csv
# mx-5m.csv
# zs-30m.csv
# kc-4h.csv
# kc-30m.csv
# zn-1d.csv
# Error: time data '04/11/1998 00:00' does not match format '%d/%m/%Y %H:%M:%S' for zn-1d.csv
# Moving to the next file ...
# eurusd-1h.csv
# eurcad-1h.csv
# ethusd-1m.csv
# Error: time data '27/03/202100 1827.02' does not match format '%d/%m/%Y %H:%M:%S' for ethusd-1m.csv
# Moving to the next file ...
# zb-1d.csv
# Error: time data '22/08/1977 00:00' does not match format '%d/%m/%Y %H:%M:%S' for zb-1d.csv
# Moving to the next file ...
# ng-1m.csv
# eurgbp-30m.csv
# gbpusd-15m.csv
# nq-1mo.csv
# audusd-1mo.csv
# si-30m.csv
# ng-30m.csv
# nifty50-1d-2007-1w.csv
# pa-1h.csv
# dax-1h.csv
# usdjpy-15m.csv
# cb-1h.csv
# cl-1m.csv
# cl-30m.csv
# rb-1w.csv
# hs-1mo.csv
# eurjpy-1mo.csv
# audjpy-15m.csv
# gbpjpy-1mo.csv
# gbpchf-1d.csv
# Error: time data '06/09/1990 00:00' does not match format '%d/%m/%Y %H:%M:%S' for gbpchf-1d.csv
# Moving to the next file ...
# audjpy-1w.csv
# nifty50-15m-2007.csv
# Error: time data '26/10/2007 06:15' does not match format '%d/%m/%Y %H:%M:%S' for nifty50-15m-2007.csv
# Moving to the next file ...
# eurchf-1m.csv
# Error: time data '07/07/2017 15:58' does not match format '%d/%m/%Y %H:%M:%S' for eurchf-1m.csv
# Moving to the next file ...
# usdjpy-1w.csv
# si-1m.csv
# eurusd-15m.csv
# vix-1mo.csv
# ftsemib1d-2004.csv
# Error: time data '26/06/2015 00:00' does not match format '%d/%m/%Y %H:%M:%S' for ftsemib1d-2004.csv
# Moving to the next file ...
# hg-1mo.csv
# cb-15m.csv
# bund-1mo.csv
# usdjpy-1d.csv
# Error: time data '01/11/1982 00:00' does not match format '%d/%m/%Y %H:%M:%S' for usdjpy-1d.csv
# Moving to the next file ...
# dax-1m.csv
# pa-1m.csv
# eurgbp-4h.csv
# cl-1h.csv
# audjpy-1d.csv
# Error: time data '04/02/1991 00:00' does not match format '%d/%m/%Y %H:%M:%S' for audjpy-1d.csv
# Moving to the next file ...
# ftsemib1d-2004-1mo.csv
# cb-1m.csv
# euraud-5m.csv
# gbpchf-1w.csv
# gbpcad-30m.csv
# eurcad-30m.csv
# rb-1d.csv
# Error: time data '27/11/1995 00:00' does not match format '%d/%m/%Y %H:%M:%S' for rb-1d.csv
# Moving to the next file ...
# dlarind-1mo.csv
# euraud-4h.csv
# zn-30m.csv
# eurgbp-5m.csv
# eurchf-1h.csv
# si-1h.csv
# gc-1mo.csv
# ym-1m.csv
# nq-1m.csv
# eurjpy-5m.csv
# zs-1m.csv
